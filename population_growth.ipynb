# %% [markdown]
# <a href="https://colab.research.google.com/github/adenikeadewumi/EEE_254/blob/main/population_growth.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Visualization of Poplation growth
#
# This willbe done by using the formula
#
#
#
#  ![Screenshot 2025-05-08 202622.png](data:image/png;base64,...)
#
#
#
#
#  Where:
#
# 𝑃
# 𝑡
# P
# t
# ​
#   is the population at time
# 𝑡
# t
#
# 𝑃
# 0
# P
# 0
# ​
#   is the initial population
#
# 𝑟
# r is the growth rate
#
# 𝑡
# t is time (in years, for example)

# %%
#Importations
import matplotlib.pyplot as plt

# %%
#Declare the variables
p_initial= 10000 #initial population
growth_rate= 0.07 #growth rate
time= 20 #in years

# Implementation using for loop
pop_lst= []
year_lst= []
for i in range(time):
  pop_lst.append(p_initial)
  year_lst.append(i)
  p_initial= p_initial*(1+growth_rate)

plt.plot(year_lst, pop_lst)
plt.xlabel('Year')
plt.ylabel('Population')
plt.title('Population Growth Over Time')
# Out:
# Text(0.5, 1.0, 'Population Growth Over Time')

# %%
#Implementation with while loop

#Declare the variables
p_initial= 10000 #initial population
growth_rate= 0.07 #growth rate
time= 20 #in years

pop_lst_while= []
year_lst_while= []
year= 0
while time>0:
  pop_lst_while.append(p_initial)
  year_lst_while.append(year)
  p_initial= p_initial*(1+growth_rate)
  year+=1
  time-=1

plt.plot(year_lst_while, pop_lst_while)
plt.xlabel('Year')
plt.ylabel('Population')
plt.title('Population Growth Over Time')
# Out:
# Text(0.5, 1.0, 'Population Growth Over Time')
